# %%
print('hi')
# Out:
# hi

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os
from groq import Groq

client = Groq(api_key=os.environ.get("GROQ_API_KEY"))

speech_file_path = "orpheus-english.wav" 
model = "canopylabs/orpheus-v1-english"
voice = "diana"
text = "ma ka bhosda aag"
response_format = "wav"

response = client.audio.speech.create(
    model=model,
    voice=voice,
    input=text,
    response_format=response_format
)

response.write_to_file(speech_file_path)

# %%
import os
import json
from groq import Groq

# Initialize the Groq client
client = Groq()

# Specify the path to the audio file
filename =  "orpheus-english.wav" # Replace with your audio file!

# Open the audio file
with open(filename, "rb") as file:
    # Create a transcription of the audio file
    transcription = client.audio.transcriptions.create(
      file=file, # Required audio file
      model="whisper-large-v3-turbo", # Required model to use for transcription
      prompt="Specify context or spelling",  # Optional
      response_format="verbose_json",  # Optional
      timestamp_granularities = ["word", "segment"], # Optional (must set response_format to "json" to use and can specify "word", "segment" (default), or both)
      language="en",  # Optional
      temperature=0.0  # Optional
    )
    # To print only the transcription text, you'd use print(transcription.text) (here we're printing the entire transcription object to access timestamps)
    print(json.dumps(transcription, indent=2, default=str))
# Out:
# "Transcription(text=' Macabre hose dog', task='transcribe', language='English', duration=4.55, words=[{'word': 'Macabre', 'start': 1.5, 'end': 2.24}, {'word': 'hose', 'start': 2.24, 'end': 2.84}, {'word': 'dog', 'start': 2.84, 'end': 3.8}], segments=[{'id': 0, 'seek': 0, 'start': 0, 'end': 4.56, 'text': ' Macabre hose dog', 'tokens': [50365, 5707, 455, 265, 20061, 3000, 50593], 'temperature': 0, 'avg_logprob': -0.52898383, 'compression_ratio': 0.6666667, 'no_speech_prob': 8.130234e-12}], x_groq={'id': 'req_01kp0rc9jvf0tbea63yng36c5y'})"

# %%
from groq import Groq
import base64
import os

# Function to encode the image
def encode_image(image_path):
  with open(image_path, "rb") as image_file:
    return base64.b64encode(image_file.read()).decode('utf-8')

# Path to your image
image_path = "house.webp"

# Getting the base64 string
base64_image = encode_image(image_path)

client = Groq(api_key=os.environ.get("GROQ_API_KEY"))

chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": [
                {"type": "text", "text": "What's in this image?"},
                {
                    "type": "image_url",
                    "image_url": {
                        "url": f"data:image/jpeg;base64,{base64_image}",
                    },
                },
            ],
        }
    ],
    model="meta-llama/llama-4-scout-17b-16e-instruct",
)

print(chat_completion.choices[0].message.content)
# Out:
# The image depicts a large, two-story house with a stone exterior and a dark roof. The house features several windows on both levels, with a covered front porch and a driveway leading to a garage. A well-manicured lawn is situated in front of the house, set against a clear blue sky.
#
# **Key Features:**
#
# * **House:**
#   * Two stories
#   * Stone exterior
#   * Dark roof
#   * Multiple windows on both levels
#   * Covered front porch
# * **Driveway and Garage:**
#   * Concrete driveway
#   * Attached garage
# * **Lawn and Surroundings:**
#   * Well-manicured lawn
#   * Clear blue sky
#   * Trees visible in the background
